# %%
# Cell 1 — cài đặt
# !pip install -q bing-image-downloader gradio tensorflow pillow matplotlib

# %%
# Cell 2 — mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 3 — cấu hình lớp và mô tả (bạn có thể sửa text mô tả cho phù hợp)
classes = {
    "life_long": "Đường sinh đạo dài (LifeLine_Long):\n\n- Thường được giải thích là người có sức sống và thể lực bền bỉ, tinh thần ổn định.\n- Người có đường sinh đạo dài thường được cho là có sức đề kháng tốt, ít ốm yếu, thích nghi nhanh.\n- (Ghi chú: đây là mô tả tham khảo giải trí, không phải chẩn đoán y tế.)",
    "life_short": "Đường sinh đạo ngắn (LifeLine_Short):\n\n- Thường được gán ý là người có thể cần chú ý hơn đến sức khỏe, đôi khi cuộc sống có nhiều thay đổi.\n- Không có nghĩa là số phận ngắn; chỉ là ký hiệu hình dạng đường sinh đôi khi ngắn so với tiêu chuẩn.",
    "head_strong": "Đường trí tuệ rõ / mạnh (HeadLine_Strong):\n\n- Biểu thị tư duy sắc bén, logic, khả năng tập trung tốt.\n- Người có đường trí đạo rõ nét được mô tả là quyết đoán, suy nghĩ thấu đáo.",
    "heart_clear": "Đường tâm rõ ràng (HeartLine_Clear):\n\n- Thể hiện sự minh bạch trong cảm xúc, khả năng biểu đạt tình cảm rõ ràng.\n- Có thể biểu thị sự cân bằng cảm xúc, dễ thân thiết với người khác.",
    "mixed": "Kiểu hỗn hợp / khó phân loại (Mixed):\n\n- Ảnh thuộc nhóm này có thể chứa nhiều yếu tố lẫn lộn (nhiều đường nhỏ, góc chụp khác nhau), hoặc không rõ rệt về một đường cụ thể.\n- Kết quả dự đoán cho nhóm này mang tính “không chắc” và dùng để hiển thị thông tin tham khảo."
}

# đặt tên thư mục dataset
dataset_dir = "palm_dataset"   # nơi lưu ảnh tải về

# %%
# Cell 4 — tải ảnh (chạy 1 lần)
import os
from bing_image_downloader import downloader

if not os.path.exists(dataset_dir):
    os.makedirs(dataset_dir, exist_ok=True)
    for label in classes.keys():
        query = f"palm lines {label} hand palm"  # query hơi generic để lấy nhiều kiểu ảnh
        out_dir = os.path.join(dataset_dir, label)
        print("Downloading for", label)
        downloader.download(query, limit=80, output_dir=dataset_dir, adult_filter_off=True, force_replace=False, timeout=60)
    print("✅ Tải xong (hoặc đã lưu).")
else:
    print("Dataset đã tồn tại, bỏ qua bước tải.")
# Out:
# Downloading for life_long
# [%] Downloading Images to /content/palm_dataset/palm lines life_long hand palm
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/4f/72/34/4f7234d47c9afca3562fbb0c70a56368.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/59/3b/e0/593be0969f11cf023e560ab3b345d613.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://theredheadriter.com/wp-content/uploads/2013/01/Read-Palm-Life-Line-Palmistry.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://images.chinahighlights.com/allpicture/2021/08/0855924323bd44aea9f757f3_748x467.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://destinypalmistry.com/wp-content/uploads/2019/07/life-line-timescale.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://chinaler.com/wp-content/uploads/2023/01/life-line.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://i.pinimg.com/736x/9d/51/58/9d51586ba2f7c4df835b8013bc18c6e6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https
jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #39 from https://blog.occultscience.in/wp-content/uploads/2024/12/Life-Line-in-Palmistry-1536x865.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #40 from https://i.pinimg.com/originals/78/b6/d2/78b6d230448308d4b1060802ecf1ccf7.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #41 from https://destinypalmistry.com/wp-content/uploads/2017/06/palmistry-short-life-line-800x855.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://i.pinimg.com/originals/86/34/46/86344688b61b63e477a9f58d03dc7ea0.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #43 from https://astrosanhita.com/wp-content/uploads/2014/07/life-line-in-plmistry.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from http://4.bp.blogspot.com/_mtmbG1w0Hfw/TOL9rv_cvnI/AAAAAAAAAXA/zoSL4Eu40qQ/s1600/life+line+on+the+palm.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #45 from https://destinypalmistry.com/wp-content/uploads/2017/10/timinglife.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from http://www.yourchineseastrology.com/images/upload/119/palm-life-line-2.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #47 from https://images.rapidload-cdn.io/spai/ret_blank,q_lossless,to_avif,w_924,h_412/https://sp-ao.shortpixel.ai/client/to_webp,q_glossy,ret_img,w_924,h_412/https://destinypalmistry.com/wp-content/uploads/2017/09/broken-life-line-jpg.webp
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://www.wikihow.com/images/thumb/0/04/Palm-Reading-Marriage-Lines-Step-1-Version-4.jpg/v4-460px-Palm-Reading-Marriage-Lines-Step-1-Version-4.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
# [%] Downloading Image #49 from https://www.chinaeducationaltours.com/media/image/2020-08/15973967952122.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #50 from https://destinypalmistry.com/wp-content/uploads/2017/06/palmistry-short-life-line-768x820.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #51 from https://i.ytimg.com/vi/ARq1qjBL6LQ/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
# [%] Downloading Image #52 from https://www.yourchineseastrology.com/images/upload/119/palm-life-line-1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
# [%] Downloading Image #53 from https://i.pinimg.com/736x/c0/e5/22/c0e522851c567d6f1abdef2ba6a7144e.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
# [%] Downloading Image #54 from https://images-sg.girlstyle.com/wp-content/uploads/2020/04/Heart-line.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://i.pinimg.com/originals/22/10/96/2210964e0b49813ac83e4fafac62f4d2.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
# [%] Downloading Image #56 from http://www.palmistry.com.au/images/palm-lines.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from https://palmistryinhand.com/wp-content/uploads/2018/05/2018-05-24_1059.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 35 Images on Page 27.
#
# ===============================================
#
# [%] Downloading Image #58 from https://i.ytimg.com/vi/zGE_6YEKU_Y/oardefault.jpg?sqp=-oaymwEkCJUDENAFSFqQAgHyq4qpAxMIARUAAAAAJQAAyEI9AICiQ3gB&amp;rs=AOn4CLAuT36lZzA3N4GYEy3_0fbHDbPkpA
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 35 Images on Page 28.
#
# ===============================================
#
# [%] Downloading Image #59 from https://static.spiritualblossom.com/media/WEBP_CACHE/filer_public/6d/46/6d46c5eb-c4b6-440b-9265-db1fb66b8db2/life_line.webp
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 35 Images on Page 29.
#
# ===============================================
#
# [%] Downloading Image #60 from https://i.pinimg.com/originals/59/cb/81/59cb8147bb571b628f9227bf95f52bc4.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 35 Images on Page 30.
#
# ===============================================
#
# [%] Downloading Image #61 from https://chinaler.com/wp-content/uploads/2023/01/MONEY-line.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 35 Images on Page 31.
#
# ===============================================
#
# [%] Downloading Image #62 from https://lh5.googleusercontent.com/sNQ4d5eE-IQMzQeRQNAuuYWoOA0apito75fcJieJc66BeEdqlC0OUdoiZ1USNZ2zfX6Nb5BZ3MFFKcnjlzfeB-K_xLXMtuTHPR-mqSEXB7zOZOR0VtXVZGfWQM94VktwYOZeG_Vy
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 32
#
# [%] Indexed 35 Images on Page 32.
#
# ===============================================
#
#
#
# [!!]Indexing page: 33
#
# [%] Indexed 35 Images on Page 33.
#
# ===============================================
#
# [%] Downloading Image #63 from https://secureservercdn.net/198.71.233.87/877.44e.myftpupload.com/wp-content/uploads/2017/10/major-lines-of-your-palm.jpg
# [!] Issue getting: https://secureservercdn.net/198.71.233.87/877.44e.myftpupload.com/wp-content/uploads/2017/10/major-lines-of-your-palm.jpg
# [!] Error:: HTTP Error 502: Bad Gateway
#
#
# [!!]Indexing page: 34
#
# [%] Indexed 35 Images on Page 34.
#
# ===============================================
#
# [%] Downloading Image #63 from https://4.bp.blogspot.com/-XC5EytcJaoY/W9WU2vtmRII/AAAAAAAAWT0/vsZiD0MElMoCCZgjuHZh1clm0caGQh71QCLcBGAs/s1600/short%2Blife%2Bline%2Bimage.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page:
jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://lh5.googleusercontent.com/sNQ4d5eE-IQMzQeRQNAuuYWoOA0apito75fcJieJc66BeEdqlC0OUdoiZ1USNZ2zfX6Nb5BZ3MFFKcnjlzfeB-K_xLXMtuTHPR-mqSEXB7zOZOR0VtXVZGfWQM94VktwYOZeG_Vy
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #48 from https://i.pinimg.com/736x/f1/45/8d/f1458d349b839eeeab15cb2df543df54--line-love-palm-reading.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #49 from https://image.shutterstock.com/z/stock-vector-palmistry-right-hand-with-lines-and-their-names-vector-illustration-on-blue-gradient-background-198363641.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://thumbs.dreamstime.com/z/palmistry-open-hand-lines-symbols-mystical-reading-illustration-flat-stock-83547507.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #51 from https://media.allure.com/photos/5b1022fdca53b936bc41ebca/master/w_775,c_limit/PalmLines_Draft1_Allure.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #52 from https://i.pinimg.com/originals/72/7f/4f/727f4f77bc2e0a47814e9da299721566.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
#
#
# [!!]Indexing page: 18
#
# [%] Indexed 35 Images on Page 18.
#
# ===============================================
#
# [%] Downloading Image #53 from https://i.pinimg.com/736x/e2/60/d5/e260d50598a58523396e2feb3abd2601.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://i.pinimg.com/736x/48/21/66/48216657a832e6c340bb90200824b00f.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 19
#
# [%] Indexed 35 Images on Page 19.
#
# ===============================================
#
# [%] Downloading Image #55 from http://image.shutterstock.com/z/stock-vector-palmistry-map-of-the-palm-s-main-lines-vector-illustration-50845966.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://i.pinimg.com/originals/70/a8/ce/70a8cecca214b929a43d9f8c5b3c6a6e.webp
# [%] File Downloaded !
#
# [%] Downloading Image #57 from https://i.pinimg.com/originals/e3/f1/a5/e3f1a5be1f86fd1766a93234a8c5b94b.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 20
#
# [%] Indexed 35 Images on Page 20.
#
# ===============================================
#
#
#
# [!!]Indexing page: 21
#
# [%] Indexed 35 Images on Page 21.
#
# ===============================================
#
#
#
# [!!]Indexing page: 22
#
# [%] Indexed 35 Images on Page 22.
#
# ===============================================
#
# [%] Downloading Image #58 from https://i.pinimg.com/originals/a5/bc/e4/a5bce4f0e0ac7b59b176bd89f843ddba.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from https://thumbs.dreamstime.com/z/vector-illustration-palm-line-palmistry-hand-palm-lines-palmistry-147970192.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 23
#
# [%] Indexed 35 Images on Page 23.
#
# ===============================================
#
# [%] Downloading Image #60 from https://psychichouseofmagic.com/wp-content/uploads/2023/05/The-lucky-triangle.png
# [!] Issue getting: https://psychichouseofmagic.com/wp-content/uploads/2023/05/The-lucky-triangle.png
# [!] Error:: Remote end closed connection without response
#
#
# [!!]Indexing page: 24
#
# [%] Indexed 35 Images on Page 24.
#
# ===============================================
#
#
#
# [!!]Indexing page: 25
#
# [%] Indexed 35 Images on Page 25.
#
# ===============================================
#
# [%] Downloading Image #60 from https://media.allure.com/photos/5b1165b649b306490becd5c6/1:1/w_767/palm-reading-lede.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 26
#
# [%] Indexed 35 Images on Page 26.
#
# ===============================================
#
#
#
# [!!]Indexing page: 27
#
# [%] Indexed 35 Images on Page 27.
#
# ===============================================
#
# [%] Downloading Image #61 from https://i.ytimg.com/vi/UYvm5-qodJs/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #62 from https://secureservercdn.net/198.71.233.87/877.44e.myftpupload.com/wp-content/uploads/2017/10/analysing-the-inner-health-line.jpg
# [!] Issue getting: https://secureservercdn.net/198.71.233.87/877.44e.myftpupload.com/wp-content/uploads/2017/10/analysing-the-inner-health-line.jpg
# [!] Error:: HTTP Error 502: Bad Gateway
#
#
# [!!]Indexing page: 28
#
# [%] Indexed 35 Images on Page 28.
#
# ===============================================
#
#
#
# [!!]Indexing page: 29
#
# [%] Indexed 35 Images on Page 29.
#
# ===============================================
#
# [%] Downloading Image #62 from https://i.pinimg.com/originals/96/48/82/964882a87c8bb64200401eba3c2f4548.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://usercontent1.hubstatic.com/13423110_f496.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 30
#
# [%] Indexed 35 Images on Page 30.
#
# ===============================================
#
# [%] Downloading Image #64 from https://i.pinimg.com/originals/a4/97/a0/a497a04c681d25ac172ea88cc4c5b9d6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://www.boldsky.com/img/2023/03/cover-1679030898.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 31
#
# [%] Indexed 35 Images on Page 31.
#
# ===============================================
#
# [%] Downloading Image #66 from https://i.pinimg.com/736x/17/ff/91/17ff91cf0396fcd4e222b9332bf40e6a.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 32
#
# [%] Indexed 35 Images on Page 32.
#
# ===============================================
#
# [%] Downloading Image #67 from https://i.pinimg.com/originals/ed/38/e0/ed38e00a4cf17948d08ad84fb7582252.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 33
#
# [%] Indexed 35 Images on Page 33.
#
# ===============================================
#
# [%] Downloading Image #68 from https://s-media-cache-ak0.pinimg.com/736x/94/37/33/943733bf49cbd7e2b404fc71fa36b44e.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from https://www.thoughtco.com/thmb/QxtlDxXXifA2hQSU8gxD9_tNP2M=/2064x1453/filters:fill(auto,1)/GettyImages-545248013-59ea5293396e5a0010859bda.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 34
#
# [%] Indexed 35 Images on Page 34.
#
# ===============================================
#
#
#
# [!!]Indexing page: 35
#
# [%] Indexed 35 Images on Page 35.
#
# ===============================================
#
# [%] Downloading Image #70 from https://astroarunpandit.org/wp-content/uploads/2025/03/Marriage-Line-Palmistry.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 35 Images on Page 36.
#
# ===============================================
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 35 Images on Page 37.
#
# ===============================================
#
# [%] Downloading Image #71 from https://i.pinimg.com/originals/0b/40/b8/0b40b8dd99b00f2c640eb02abeee991b.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 38
#
# [%] Indexed 35 Images on Page 38.
#
# ===============================================
#
# [%] Downloading Image #72 from https://i.pinimg.com/originals/5c/0c/fb/5c0cfba56b827632ec5fbbad03c6dd97.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://i.pinimg.com/originals/02/29/20/022920d6bbe09baa54c11b5c657aac29.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 39
#
# [%] Indexed 35 Images on Page 39.
#
# ===============================================
#
# [%] Downloading Image #74 from https://i.pinimg.com/736x/3f/b7/d9/3fb7d9f8d7b93cbc03ff6c2295aeb1d5.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 40
#
# [%] Indexed 35 Images on Page 40.
#
# ===============================================
#
#
#
# [!!]Indexing page: 41
#
# [%] Indexed 35 Images on Page 41.
#
# ===============================================
#
# [%] Downloading Image #75 from https://i.pinimg.com/originals/1f/f4/bd/1ff4bde2f5d5eb57fc5df218c28bfe6d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #76 from https://i.pinimg.com/originals/13/64/4d/13644dd16afc5c9a8e0b0d3ce74c44f9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://destinypalmistry.com/wp-content/uploads/2019/10/Lines-on-the-palm.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 42
#
# [%] Indexed 35 Images on Page 42.
#
# ===============================================
#
#
#
# [!!]Indexing page: 43
#
# [%] Indexed 35 Images on Page 43.
#
# ===============================================
#
# [%] Downloading Image #78 from https://i.pinimg.com/originals/c6/33/9a/c6339ae11be542757b17da7830089338.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 44
#
# [%] Indexed 35 Images on Page 44.
#
# ===============================================
#
#
#
# [!!]Indexing page: 45
#
# [%] Indexed 35 Images on Page 45.
#
# ===============================================
#
#
#
# [!!]Indexing page: 46
#
# [%] Indexed 35 Images on Page 46.
#
# ===============================================
#
# [%] Downloading Image #79 from https://i.pinimg.com/originals/88/a6/7d/88a67dbc0f0098842bd46eaa69ca8f82.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 47
#
# [%] Indexed 35 Images on Page 47.
#
# ===============================================
#
# [%] Downloading Image #80 from https://astrotalk.com/astrology-blog/wp-content/uploads/2023/04/palm-g2bd390115_640.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 80 images.
# ✅ Tải xong (hoặc đã lưu).

# %%
# Cell 5 — chuẩn hóa tên thư mục con
import shutil, glob

# tìm thư mục con do bing tạo và map về tên label nếu cần
subdirs = [d for d in glob.glob(dataset_dir + "/*") if os.path.isdir(d)]
print("Thư mục con hiện có:", subdirs)

# nếu bing tạo folder giống query, ta sẽ match bằng chứa tên label
for d in subdirs:
    name = os.path.basename(d).lower()
    for label in classes.keys():
        if label.replace("_"," ") in name or label in name:
            # move files into desired folder
            target = os.path.join(dataset_dir, label)
            if not os.path.exists(target):
                os.makedirs(target, exist_ok=True)
            # move images
            for f in os.listdir(d):
                src = os.path.join(d, f)
                dst = os.path.join(target, f)
                try:
                    shutil.move(src, dst)
                except:
                    pass
            # remove empty dir
            try:
                os.rmdir(d)
            except:
                pass

# nếu còn folder không đúng tên, in ra để bạn kiểm tra
print("Sau chuẩn hoá, thư mục con:", [d for d in os.listdir(dataset_dir)])
# Out:
# Thư mục con hiện có: ['palm_dataset/palm lines life_long hand palm', 'palm_dataset/palm lines life_short hand palm', 'palm_dataset/palm lines heart_clear hand palm', 'palm_dataset/palm lines mixed hand palm', 'palm_dataset/palm lines head_strong hand palm']
# Sau chuẩn hoá, thư mục con: ['life_short', 'mixed', 'life_long', 'head_strong', 'heart_clear']

# %%
# Cell 6 — dọn ảnh corrupted, quá nhỏ và in số lượng
from PIL import Image

min_wh = 40
removed = 0
for label in classes.keys():
    folder = os.path.join(dataset_dir, label)
    if not os.path.exists(folder):
        print("Warning: folder missing:", folder)
        continue
    files = os.listdir(folder)
    for fn in files:
        fp = os.path.join(folder, fn)
        try:
            im = Image.open(fp)
            im.verify()  # kiểm tra ảnh bị lỗi
            im = Image.open(fp)
            w,h = im.size
            if w < min_wh or h < min_wh:
                os.remove(fp); removed += 1
        except:
            try:
                os.remove(fp); removed += 1
            except:
                pass
print(f"Đã xóa {removed} file hỏng/quá nhỏ.")

# in thống kê
for label in classes.keys():
    folder = os.path.join(dataset_dir, label)
    cnt = len(os.listdir(folder)) if os.path.exists(folder) else 0
    print(f"{label}: {cnt} ảnh")
# Out:
# Đã xóa 0 file hỏng/quá nhỏ.
# life_long: 80 ảnh
# life_short: 80 ảnh
# head_strong: 80 ảnh
# heart_clear: 80 ảnh
# mixed: 80 ảnh

# %%
# Cell 7 — tạo train/test bằng ImageDataGenerator (tự chia bằng validation_split)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = (128,128)
BATCH = 16

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.12,
    height_shift_range=0.12,
    shear_range=0.12,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest",
    validation_split=0.18
)

train_gen = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH,
    class_mode="categorical",
    subset="training",
    shuffle=True
)

val_gen = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH,
    class_mode="categorical",
    subset="validation",
    shuffle=False
)

# lưu labels vào drive để load sau này
import pickle
labels = list(train_gen.class_indices.keys())
with open("/content/drive/MyDrive/palm_labels.pkl", "wb") as f:
    pickle.dump(labels, f)
print("Classes:", labels)
# Out:
# Found 317 images belonging to 5 classes.
# Found 67 images belonging to 5 classes.
# Classes: ['head_strong', 'heart_clear', 'life_long', 'life_short', 'mixed']

# %%
# Cell 8 — xây ANN và train
from tensorflow.keras import layers, models, callbacks
import tensorflow as tf

num_classes = len(labels)

model = models.Sequential([
    layers.Flatten(input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
    layers.Dense(1024, activation="relu"),
    layers.Dropout(0.4),
    layers.Dense(512, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(256, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation="softmax")
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.summary()

# callbacks
chk = callbacks.ModelCheckpoint("/content/drive/MyDrive/palm_model_best.h5", save_best_only=True, monitor="val_accuracy", mode="max")
es = callbacks.EarlyStopping(monitor="val_loss", patience=6, restore_best_weights=True)

history = model.fit(train_gen, validation_data=val_gen, epochs=30, callbacks=[chk, es])
print("✅ Train hoàn thành. Model tốt nhất đã lưu lên Drive.")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 49152)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    50,332,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,990,085 (194.51 MB)
#  Trainable params: 50,990,085 (194.51 MB)
#  Non-trainable params: 0 (0.00 B)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
#  3/20 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.2465 - loss: 3.2741
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2024 - loss: 5.2285
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.2023 - loss: 5.2617 - val_accuracy: 0.2090 - val_loss: 2.3996
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2196 - loss: 6.4858
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.2202 - loss: 6.4490 - val_accuracy: 0.2239 - val_loss: 2.0190
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.2011 - loss: 4.1073 - val_accuracy: 0.2239 - val_loss: 1.7769
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2075 - loss: 3.2571 - val_accuracy: 0.1791 - val_loss: 2.1993
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.2142 - loss: 2.4951 - val_accuracy: 0.1940 - val_loss: 1.7265
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1785 - loss: 1.9727 - val_accuracy: 0.1940 - val_loss: 1.6498
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.2184 - loss: 1.6570 - val_accuracy: 0.2090 - val_loss: 1.6100
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1571 - loss: 1.6082 - val_accuracy: 0.1791 - val_loss: 1.6099
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1641 - loss: 1.6133 - val_accuracy: 0.1940 - val_loss: 1.6101
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.2010 - loss: 1.6149 - val_accuracy: 0.2090 - val_loss: 1.6094
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.1813 - loss: 1.6094 - val_accuracy: 0.1940 - val_loss: 1.6096
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1969 - loss: 1.6094 - val_accuracy: 0.1940 - val_loss: 1.6101
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1881 - loss: 1.6094 - val_accuracy: 0.1940 - val_loss: 1.6106
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.2293 - loss: 1.6096 - val_accuracy: 0.1791 - val_loss: 1.6063
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1816 - loss: 1.6227 - val_accuracy: 0.1940 - val_loss: 1.6103
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.2210 - loss: 1.6083 - val_accuracy: 0.1642 - val_loss: 1.6106
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1823 - loss: 1.6113 - val_accuracy: 0.1940 - val_loss: 1.6108
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.1960 - loss: 1.6298 - val_accuracy: 0.1940 - val_loss: 1.6108
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1809 - loss: 1.6096 - val_accuracy: 0.1940 - val_loss: 1.6112
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.2344 - loss: 1.6110 - val_accuracy: 0.1940 - val_loss: 1.6104
# ✅ Train hoàn thành. Model tốt nhất đã lưu lên Drive.

# %%
# Cell 9 — load nhanh khi mở lại Colab
from tensorflow.keras.models import load_model
import pickle

model = load_model("/content/drive/MyDrive/palm_model_best.h5")
with open("/content/drive/MyDrive/palm_labels.pkl", "rb") as f:
    labels = pickle.load(f)

print("✅ Đã load model và labels:", labels)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Đã load model và labels: ['head_strong', 'heart_clear', 'life_long', 'life_short', 'mixed']

# %%
# Cell 10 — hàm dự đoán trả top-3 + mô tả dài
import numpy as np
from PIL import Image

def predict_palm(img_pil):
    img = img_pil.resize(IMG_SIZE)
    x = np.array(img) / 255.0
    x = np.expand_dims(x, 0)
    preds = model.predict(x)[0]
    idxs = np.argsort(preds)[-3:][::-1]
    results = []
    for i in idxs:
        results.append({"label": labels[i], "score": float(preds[i]), "desc": classes[labels[i]]})
    return results

# %%
# Cell 11 — lưu feedback và update model function
import os
feedback_dir = "/content/drive/MyDrive/palm_feedback"
os.makedirs(feedback_dir, exist_ok=True)

def save_feedback(img_pil, correct_label):
    if correct_label not in labels:
        return f"Nhãn không hợp lệ. Hợp lệ: {labels}"
    label_dir = os.path.join(feedback_dir, correct_label)
    os.makedirs(label_dir, exist_ok=True)
    cnt = len(os.listdir(label_dir))
    path = os.path.join(label_dir, f"fb_{cnt}.jpg")
    img_pil.save(path)
    return f"Đã lưu feedback vào {path}"

def update_from_feedback():
    # fine-tune model trên feedback nếu có
    gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
    if not os.path.exists(feedback_dir):
        return "Chưa có feedback."
    # ensure folders exist
    sub = [d for d in os.listdir(feedback_dir) if os.path.isdir(os.path.join(feedback_dir,d))]
    if len(sub) == 0:
        return "Chưa có feedback."
    fb_flow = gen.flow_from_directory(feedback_dir, target_size=IMG_SIZE, batch_size=8, class_mode="categorical")
    if fb_flow.samples == 0:
        return "Chưa có feedback."
    model.fit(fb_flow, epochs=3)
    model.save("/content/drive/MyDrive/palm_model_best.h5")
    return f"Đã cập nhật model từ feedback ({fb_flow.samples} ảnh)."

# %%
# Cell 12 — Web Gradio
import gradio as gr

def gr_predict(img):
    res = predict_palm(img)
    # hiển thị top1 text + bottom top3 probabilities
    top = res[0]
    summary = f"**Dự đoán chính:** {top['label']} — độ tin cậy {top['score']*100:.1f}%\n\n{top['desc']}"
    probs = {r['label']: round(r['score'], 4) for r in res}
    return summary, probs

def gr_feedback(img, correct_label):
    return save_feedback(img, correct_label)

def gr_update():
    return update_from_feedback()

with gr.Blocks() as demo:
    gr.Markdown("# 🖐️ PalmLines AI — Phân tích chỉ tay (demo giải trí)")
    with gr.Row():
        with gr.Column(scale=2):
            inp = gr.Image(type="pil", label="Tải ảnh lòng bàn tay lên (nền sáng, rõ đường)")
            btn = gr.Button("Dự đoán")
            out_text = gr.Markdown()
        with gr.Column(scale=1):
            gr.Markdown("### Top-3 dự đoán")
            out_label = gr.Label(num_top_classes=3)
            gr.Markdown("### Nếu sai, nhập nhãn đúng:")
            correct = gr.Dropdown(choices=labels, label="Chọn nhãn đúng (feedback)")
            fb_btn = gr.Button("Lưu feedback")
            fb_msg = gr.Textbox(label="Thông báo")
            upd_btn = gr.Button("Cập nhật mô hình từ feedback")
            upd_msg = gr.Textbox(label="Kết quả cập nhật")

    btn.click(gr_predict, inputs=inp, outputs=[out_text, out_label])
    fb_btn.click(gr_feedback, inputs=[inp, correct], outputs=fb_msg)
    upd_btn.click(gr_update, outputs=upd_msg)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4f6c753a258814657a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4f6c753a258814657a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
